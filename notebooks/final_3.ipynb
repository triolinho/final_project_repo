# %%
import config
from bs4 import BeautifulSoup as BS
import requests
import mysql.connector
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import json
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import *
import time
import re
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import Reader
from surprise.model_selection import train_test_split
from surprise import accuracy
from surprise import KNNBasic
from surprise.model_selection import GridSearchCV
from sklearn.metrics.pairwise import cosine_similarity
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import calinski_harabasz_score
from sklearn.decomposition import PCA

# %%
df_stats_total = pd.read_csv('df_stats_merged.csv', index_col='team')

# %%
df_stats_total4 = pd.read_csv('df_stats_merged4.csv', index_col='team')

# %%
df_stats_total6 = pd.read_csv('df_stats_merged6.csv', index_col='team')

# %%
df_stats_poss2 = pd.read_csv('df_stats_poss2.csv', index_col='Team')

# %%
df_stats_poss2.head()
# Out:
#                                CR       ACR       CCOP      CCSP         FS  \
# Team
# Bayern Munich           22.852941  5.911765  10.000000  2.088235  10.176471
# Borussia Dortmund       13.470588  3.352941   6.882353  1.235294  11.441176
# RasenBallsport Leipzig  18.117647  4.588235   8.470588  1.558824  11.764706
# Bayer Leverkusen        18.882353  4.617647   8.970588  1.000000  11.764706
# Borussia M.Gladbach     16.617647  4.117647   7.588235  1.352941  10.735294
#
#                                  P         DR        IBS       OBS        DSP  \
# Team
# Bayern Munich           571.000000  12.500000  12.794118  6.000000   9.323529
# Borussia Dortmund       524.352941  12.941176   8.852941  4.352941  11.205882
# RasenBallsport Leipzig  335.911765   9.264706  10.147059  4.470588  11.588235
# Bayer Leverkusen        536.764706   9.970588  10.058824  5.735294  11.911765
# Borussia M.Gladbach     436.617647   8.205882   8.411765  5.147059   8.941176
#
#                         ...         AW         BR         DW        SV  \
# Team                    ...
# Bayern Munich           ...  15.705882  64.029412  51.558824  1.411765
# Borussia Dortmund       ...  13.970588  58.970588  52.441176  2.647059
# RasenBallsport Leipzig  ...  22.500000  65.705882  61.941176  2.794118
# Bayer Leverkusen        ...  16.882353  68.147059  55.441176  2.705882
# Borussia M.Gladbach     ...  13.147059  56.970588  46.029412  3.382353
#
#                              AKS       PKC         CL     PUNCH       LMT  \
# Team
# Bayern Munich           0.323529  0.176471  10.117647  0.088235  0.029412
# Borussia Dortmund       0.088235  0.147059  18.470588  0.382353  0.029412
# RasenBallsport Leipzig  0.500000  0.176471  19.647059  0.176471  0.088235
# Bayer Leverkusen        0.441176  0.176471  18.882353  0.264706  0.000000
# Borussia M.Gladbach     0.088235  0.088235  17.294118  0.117647  0.058824
#
#                          poss
# Team
# Bayern Munich           0.622
# Borussia Dortmund       0.568
# RasenBallsport Leipzig  0.495
# Bayer Leverkusen        0.577
# Borussia M.Gladbach     0.523
#
# [5 rows x 32 columns]

# %%
df_stats_poss2 = df_stats_poss2.drop(df_stats_poss2.columns[0], axis=1)

# %%
df_leagues = pd.read_csv('df_stats_leagues.csv', index_col=0)

# %%
df_leagues.columns
# Out:
# Index(['league', 'team'], dtype='object')

# %%
df_leagues.shape
# Out:
# (98, 2)

# %%
df_leagues.head()
# Out:
#        league                    team
# 0  Bundesliga           Bayern Munich
# 1  Bundesliga       Borussia Dortmund
# 4  Bundesliga  RasenBallsport Leipzig
# 2  Bundesliga        Bayer Leverkusen
# 8  Bundesliga     Borussia M.Gladbach

# %%
df_leagues['team']
# Out:
# 0              Bayern Munich
# 1          Borussia Dortmund
# 4     RasenBallsport Leipzig
# 2           Bayer Leverkusen
# 8        Borussia M.Gladbach
#                ...
# 14         Parma Calcio 1913
# 15                     Genoa
# 10                    Empoli
# 18                 Frosinone
# 19                    Chievo
# Name: team, Length: 98, dtype: object

# %%
df_stats_total4.head(10)
# Out:
#                         INT   CR  ACR  CCOP  CCSP  BLK  TKL   FC   FS      P  \
# team
# Bayern Munich           336  777  201   340    71   61  464  312  346  19414
# Borussia Dortmund       385  458  114   234    42   79  497  292  389  17828
# RasenBallsport Leipzig  420  616  156   288    53   70  653  465  400  11421
# Bayer Leverkusen        364  642  157   305    34   99  598  370  400  18250
# Borussia M.Gladbach     310  565  140   258    46  102  500  332  365  14845
# Wolfsburg               430  681  176   226    48   95  540  358  445  12164
# Eintracht Frankfurt     380  686  155   210    55  103  612  432  353   9861
# Werder Bremen           407  676  164   274    39  109  552  437  350  13366
# Hoffenheim              400  666  179   364    56  104  574  471  355  13450
# Fortuna Duesseldorf     427  563  158   230    51  112  635  443  424  10732
#
#                         ...   SV  AKS  PKC   CL  PUNCH   ALB  ATB  LMT  TOFF  \
# team                    ...
# Bayern Munich           ...   48   11    6  344      3  1292   31    1    88
# Borussia Dortmund       ...   90    3    5  628     13   981   36    1    64
# RasenBallsport Leipzig  ...   95   17    6  668      6   864   29    3    87
# Bayer Leverkusen        ...   92   15    6  642      9  1197   23    0    66
# Borussia M.Gladbach     ...  115    3    3  588      4  1067   19    2    70
# Wolfsburg               ...  110    5    6  739     17  1449   16    4    67
# Eintracht Frankfurt     ...  127   13    1  669     14  1094   20    1    84
# Werder Bremen           ...  108    5    5  773     14  1086   14    2    40
# Hoffenheim              ...  123    7    7  603      8   952   17    3    66
# Fortuna Duesseldorf     ...  117    4    8  751     25  1228   18    2    50
#
#                         BCS
# team
# Bayern Munich            52
# Borussia Dortmund        51
# RasenBallsport Leipzig   38
# Bayer Leverkusen         44
# Borussia M.Gladbach      30
# Wolfsburg                37
# Eintracht Frankfurt      45
# Werder Bremen            30
# Hoffenheim               42
# Fortuna Duesseldorf      31
#
# [10 rows x 31 columns]

# %%
cos_sim = cosine_similarity(df_scaled2)

# %%
cos_sim[0:5]
# Out:
# array([[1.        , 0.99954729, 0.99007659, 0.99954669, 0.99935514,
#         0.99361386, 0.98089331, 0.99699889, 0.99714505, 0.98976937,
#         0.99300537, 0.98961308, 0.99151727, 0.98735055, 0.98884966,
#         0.9881916 , 0.98945264, 0.98884191, 0.99946341, 0.99976695,
#         0.999712  , 0.9991171 , 0.99901042, 0.9981412 , 0.9917409 ,
#         0.99033584, 0.99232103, 0.99340268, 0.98953904, 0.98892853,
#         0.97828392, 0.99325531, 0.9721837 , 0.98376295, 0.9846254 ,
#         0.93363036, 0.99536037, 0.99004386, 0.99953034, 0.99470082,
#         0.99960833, 0.9932247 , 0.99441545, 0.94401304, 0.99384273,
#         0.98908499, 0.9860434 , 0.99680112, 0.99767413, 0.99273913,
#         0.99506392, 0.99649296, 0.99326644, 0.99234857, 0.99690124,
#         0.99407256, 0.9875532 , 0.98741524, 0.99977617, 0.99952751,
#         0.99953278, 0.99963006, 0.99979331, 0.99820741, 0.99112078,
#         0.99880973, 0.99962048, 0.99090157, 0.9995898 , 0.9907127 ,
#         0.99776861, 0.99549548, 0.99691474, 0.98630865, 0.9876051 ,
#         0.99905718, 0.9911627 , 0.9939819 ]])

# %%
epl_array = (df_leagues['team'][df_leagues['league'] == 'EPL']).tolist()
ligue_1_array = (df_leagues['team'][df_leagues['league'] == 'Ligue_1']).tolist()
serie_a_array = (df_leagues['team'][df_leagues['league'] == 'Serie_A']).tolist()
la_liga_array = (df_leagues['team'][df_leagues['league'] == 'La_liga']).tolist()
bundesliga_array = (df_leagues['team'][df_leagues['league'] == 'Bundesliga']).tolist()

# %%
# creating a Series for the movie titles so they are associated to an ordered numerical
# list I will use in the function to match the indexes
indices = pd.Series(df_scaled2.index)
#  defining the function that takes in movie title 
# as input and returns the top 10 recommended movies
def recommendations(team, cosine_sim = cos_sim):
    
    epl_array = (df_leagues['team'][df_leagues['league'] == 'EPL']).tolist()
    ligue_1_array = (df_leagues['team'][df_leagues['league'] == 'Ligue_1']).tolist()
    serie_a_array = (df_leagues['team'][df_leagues['league'] == 'Serie_A']).tolist()
    la_liga_array = (df_leagues['team'][df_leagues['league'] == 'La_liga']).tolist()
    bundesliga_array = (df_leagues['team'][df_leagues['league'] == 'Bundesliga']).tolist()
    
    en_teams = []
    fr_teams = []
    it_teams = []
    sp_teams = []
    ge_teams = []
    
    # initializing the empty list of recommended movies
    recommended_teams = []
    
    # gettin the index of the movie that matches the title
    idx = indices[indices == team].index[0]
    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)
    # getting the indexes of the 10 most similar movies
    all_indexes = list(score_series.index)
    
    # populating the list with the titles of the best 10 matching movies
    for i in all_indexes:
        recommended_teams.append(list(df_scaled2.index)[i])
    
    if recommended_teams[0] in epl_array:
        for i in recommended_teams:
            if i in ligue_1_array:
                fr_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
            
        print(fr_teams[0], it_teams[0], sp_teams[0], ge_teams[0])
    
    elif recommended_teams[0] in ligue_1_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
        print(en_teams[0], it_teams[0], sp_teams[0], ge_teams[0])
    
    elif recommended_teams[0] in serie_a_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in ligue_1_array:
                fr_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
        print(en_teams[0], fr_teams[0], sp_teams[0], ge_teams[0])
    
    elif recommended_teams[0] in la_liga_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in ligue_1_array:
                fr_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
        print(en_teams[0], fr_teams[0], it_teams[0], ge_teams[0])
        
    elif recommended_teams[0] in bundesliga_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in ligue_1_array:
                fr_teams.append(i)
        print(en_teams[0], fr_teams[0], it_teams[0], sp_teams[0])
    
    else:
        print('not applicable')
    
    return

# %%
recommendations('Paris Saint Germain')
# Out:
# Chelsea Atalanta Barcelona Borussia Dortmund

# %%
for team in df_leagues['team']:
    print(team , recommendations(team), '++++++++')
# Out:
# Manchester City Lyon Atalanta Real Madrid
# Bayern Munich None ++++++++
# Chelsea Paris Saint Germain Atalanta Barcelona
# Borussia Dortmund None ++++++++
# Everton Marseille Atalanta Eibar
# RasenBallsport Leipzig None ++++++++
# Liverpool Lyon Atalanta Real Madrid
# Bayer Leverkusen None ++++++++
# Manchester United Paris Saint Germain Napoli Barcelona
# Borussia M.Gladbach None ++++++++
# Wolverhampton Wanderers Strasbourg Juventus Eibar
# Wolfsburg None ++++++++
# Everton Nantes Torino Eibar
# Eintracht Frankfurt None ++++++++
# Manchester City Saint-Etienne Roma Valencia
# Werder Bremen None ++++++++
# Manchester City Lyon Atalanta Real Madrid
# Hoffenheim None ++++++++
# Newcastle United Montpellier Udinese Leganes
# Fortuna Duesseldorf None ++++++++
# Brighton Caen Parma Calcio 1913 Villarreal
# Hertha Berlin None ++++++++
# Fulham Montpellier Lazio Valencia
# Mainz 05 None ++++++++
# Newcastle United Caen Udinese Espanyol
# Freiburg None ++++++++
# Everton Nantes Genoa Atletico Madrid
# Schalke 04 None ++++++++
# Brighton Dijon Chievo SD Huesca
# Augsburg None ++++++++
# Cardiff Guingamp Frosinone Alaves
# VfB Stuttgart None ++++++++
# Cardiff Caen Parma Calcio 1913 Girona
# Hannover 96 None ++++++++
# Cardiff Angers Parma Calcio 1913 Leganes
# Nuernberg None ++++++++
# Paris Saint Germain Napoli Real Madrid Bayern Munich
# Manchester City None ++++++++
# Paris Saint Germain Atalanta Real Madrid Bayern Munich
# Liverpool None ++++++++
# Paris Saint Germain Napoli Barcelona Bayern Munich
# Chelsea None ++++++++
# Paris Saint Germain Napoli Barcelona Bayer Leverkusen
# Tottenham None ++++++++
# Paris Saint Germain Empoli Sevilla Borussia Dortmund
# Arsenal None ++++++++
# Paris Saint Germain Napoli Barcelona Borussia M.Gladbach
# Manchester United None ++++++++
# Caen Chievo Atletico Madrid Augsburg
# Wolverhampton Wanderers None ++++++++
# Marseille Genoa Eibar RasenBallsport Leipzig
# Everton None ++++++++
# Nice Empoli Atletico Madrid Hannover 96
# West Ham None ++++++++
# Marseille Atalanta Eibar VfB Stuttgart
# Leicester None ++++++++
# Toulouse Sampdoria Alaves VfB Stuttgart
# Watford None ++++++++
# Reims Udinese Atletico Madrid Hannover 96
# Crystal Palace None ++++++++
# Huddersfield Torino Real Valladolid Freiburg
# Bordeaux None ++++++++
# Watford Bologna Alaves Nuernberg
# Toulouse None ++++++++
# Brighton Chievo Girona Nuernberg
# Amiens None ++++++++
# Everton SPAL 2013 Real Valladolid Nuernberg
# Monaco None ++++++++
# Huddersfield Torino Alaves Augsburg
# Dijon None ++++++++
# Brighton Chievo Girona Hannover 96
# Caen None ++++++++
# Huddersfield Genoa Alaves VfB Stuttgart
# Guingamp None ++++++++
# Manchester City Lyon Real Madrid Bayern Munich
# Juventus None ++++++++
# Chelsea Lyon Real Madrid Hoffenheim
# Napoli None ++++++++
# Manchester City Paris Saint Germain Real Madrid Hoffenheim
# Atalanta None ++++++++
# Manchester City Saint-Etienne Real Madrid Bayern Munich
# Inter None ++++++++
# Manchester City Saint-Etienne Real Madrid Hoffenheim
# AC Milan None ++++++++
# Manchester City Lyon Real Madrid Hoffenheim
# Roma None ++++++++
# Huddersfield Montpellier Getafe Eintracht Frankfurt
# Torino None ++++++++
# Manchester City Lyon Real Madrid Hoffenheim
# Lazio None ++++++++
# Arsenal Lille Real Betis Bayer Leverkusen
# Sampdoria None ++++++++
# Cardiff Nantes Alaves Freiburg
# Bologna None ++++++++
# Manchester United Lille Real Betis Borussia M.Gladbach
# Sassuolo None ++++++++
# Fulham Amiens Espanyol Freiburg
# Udinese None ++++++++
# Bournemouth Monaco Girona Nuernberg
# SPAL 2013 None ++++++++
# Manchester City Nimes Valencia Hoffenheim
# Fiorentina None ++++++++
# Brighton Strasbourg Girona Werder Bremen
# Cagliari None ++++++++
# Brighton Amiens Espanyol Freiburg
# Parma Calcio 1913 None ++++++++
# Southampton Nimes Leganes Schalke 04
# Genoa None ++++++++
# Arsenal Strasbourg Levante Borussia M.Gladbach
# Empoli None ++++++++
# Brighton Amiens Girona Freiburg
# Frosinone None ++++++++
# Brighton Caen Girona Freiburg
# Chievo None ++++++++

# %%
# creating a Series for the movie titles so they are associated to an ordered numerical
# list I will use in the function to match the indexes
indices = pd.Series(df_scaled2.index)
#  defining the function that takes in movie title 
# as input and returns the top 10 recommended movies
def opposites(team, cosine_sim = cos_sim):
    
    epl_array = (df_leagues['team'][df_leagues['league'] == 'EPL']).tolist()
    ligue_1_array = (df_leagues['team'][df_leagues['league'] == 'Ligue_1']).tolist()
    serie_a_array = (df_leagues['team'][df_leagues['league'] == 'Serie_A']).tolist()
    la_liga_array = (df_leagues['team'][df_leagues['league'] == 'La_liga']).tolist()
    bundesliga_array = (df_leagues['team'][df_leagues['league'] == 'Bundesliga']).tolist()
    
    en_teams = []
    fr_teams = []
    it_teams = []
    sp_teams = []
    ge_teams = []
    
    # initializing the empty list of recommended movies
    recommended_teams = []
    
    # gettin the index of the movie that matches the title
    idx = indices[indices == team].index[0]
    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)
    # getting the indexes of the 10 most similar movies
    all_indexes = list(score_series.index)
    
    # populating the list with the titles of the best 10 matching movies
    for i in all_indexes:
        recommended_teams.append(list(df_scaled2.index)[i])
    
    if recommended_teams[0] in epl_array:
        for i in recommended_teams:
            if i in ligue_1_array:
                fr_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
            
        print(fr_teams[-1], it_teams[-1], sp_teams[-1], ge_teams[-1])
    
    elif recommended_teams[0] in ligue_1_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
        print(en_teams[-1], it_teams[-1], sp_teams[-1], ge_teams[-1])
    
    elif recommended_teams[0] in serie_a_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in ligue_1_array:
                fr_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
        print(en_teams[-1], fr_teams[-1], sp_teams[-1], ge_teams[-1])
    
    elif recommended_teams[0] in la_liga_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in ligue_1_array:
                fr_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
        print(en_teams[-1], fr_teams[-1], it_teams[-1], ge_teams[-1])
        
    elif recommended_teams[0] in bundesliga_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in ligue_1_array:
                fr_teams.append(i)
        print(en_teams[-1], fr_teams[-1], it_teams[-1], sp_teams[-1])
    
    else:
        print('not applicable')
    
    return

# %%
opposites('Liverpool')
# Out:
# ['Guingamp', 'Reims', 'Dijon', 'Amiens', 'Caen'] ['Genoa', 'Udinese', 'Parma Calcio 1913', 'Frosinone', 'Chievo'] ['Leganes', 'Real Valladolid', 'SD Huesca', 'Alaves', 'Girona'] ['Fortuna Duesseldorf', 'Nuernberg', 'Freiburg', 'Augsburg', 'Hannover 96']

# %%
for team in df_leagues['team']:
    print(team , opposites(team), '++++++++')
# Out:
# Brighton Caen Chievo Alaves
# Bayern Munich None ++++++++
# Newcastle United Dijon Bologna Alaves
# Borussia Dortmund None ++++++++
# Fulham Strasbourg Udinese Espanyol
# RasenBallsport Leipzig None ++++++++
# Brighton Amiens Chievo Alaves
# Bayer Leverkusen None ++++++++
# Everton Nantes Torino Getafe
# Borussia M.Gladbach None ++++++++
# Crystal Palace Rennes Sampdoria Celta Vigo
# Wolfsburg None ++++++++
# Manchester United Nice Sassuolo Real Betis
# Eintracht Frankfurt None ++++++++
# West Ham Toulouse Bologna Celta Vigo
# Werder Bremen None ++++++++
# Huddersfield Caen Parma Calcio 1913 Girona
# Hoffenheim None ++++++++
# Manchester City Lyon Inter Real Betis
# Fortuna Duesseldorf None ++++++++
# Tottenham Saint-Etienne AC Milan Real Betis
# Hertha Berlin None ++++++++
# Arsenal Monaco Sampdoria Real Betis
# Mainz 05 None ++++++++
# Chelsea Paris Saint Germain Atalanta Sevilla
# Freiburg None ++++++++
# Manchester United Strasbourg Empoli Espanyol
# Schalke 04 None ++++++++
# Liverpool Paris Saint Germain Real Madrid Bayer Leverkusen
# Frosinone None ++++++++
# Liverpool Lyon Real Madrid Bayern Munich
# Chievo None ++++++++

# %%
# creating a Series for the movie titles so they are associated to an ordered numerical
# list I will use in the function to match the indexes
indices = pd.Series(df_stats_total4.index)
#  defining the function that takes in movie title 
# as input and returns the top 10 recommended movies
def l_recommendations(team, cosine_sim = cos_sim):
    
    epl_array = (df_leagues['team'][df_leagues['league'] == 'EPL']).tolist()
    ligue_1_array = (df_leagues['team'][df_leagues['league'] == 'Ligue_1']).tolist()
    serie_a_array = (df_leagues['team'][df_leagues['league'] == 'Serie_A']).tolist()
    la_liga_array = (df_leagues['team'][df_leagues['league'] == 'La_liga']).tolist()
    bundesliga_array = (df_leagues['team'][df_leagues['league'] == 'Bundesliga']).tolist()
    
    en_teams = []
    fr_teams = []
    it_teams = []
    sp_teams = []
    ge_teams = []
    
    # initializing the empty list of recommended movies
    recommended_teams = []
    
    # gettin the index of the movie that matches the title
    idx = indices[indices == team].index[0]
    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)
    # getting the indexes of the 10 most similar movies
    all_indexes = list(score_series.index)
    
    print(score_series)
    
    # populating the list with the titles of the best 10 matching movies
#     for i in all_indexes:
#         recommended_teams.append(list(df_stats_total4.index)[i])
    
#     if recommended_teams[0] in epl_array:
#         for i in recommended_teams:
#             if i in ligue_1_array:
#                 fr_teams.append(i)
#             if i in serie_a_array:
#                 it_teams.append(i)
#             if i in la_liga_array:
#                 sp_teams.append(i)
#             if i in bundesliga_array:
#                 ge_teams.append(i)
            
#         print(fr_teams[0], it_teams[0], sp_teams[0], ge_teams[0])
    
#     elif recommended_teams[0] in ligue_1_array:
#         for i in recommended_teams:
#             if i in epl_array:
#                 en_teams.append(i)
#             if i in serie_a_array:
#                 it_teams.append(i)
#             if i in la_liga_array:
#                 sp_teams.append(i)
#             if i in bundesliga_array:
#                 ge_teams.append(i)
#         print(en_teams[0], it_teams[0], sp_teams[0], ge_teams[0])
    
#     elif recommended_teams[0] in serie_a_array:
#         for i in recommended_teams:
#             if i in epl_array:
#                 en_teams.append(i)
#             if i in ligue_1_array:
#                 fr_teams.append(i)
#             if i in la_liga_array:
#                 sp_teams.append(i)
#             if i in bundesliga_array:
#                 ge_teams.append(i)
#         print(en_teams[0], fr_teams[0], sp_teams[0], ge_teams[0])
    
#     elif recommended_teams[0] in la_liga_array:
#         for i in recommended_teams:
#             if i in epl_array:
#                 en_teams.append(i)
#             if i in serie_a_array:
#                 it_teams.append(i)
#             if i in ligue_1_array:
#                 fr_teams.append(i)
#             if i in bundesliga_array:
#                 ge_teams.append(i)
#         print(en_teams[0], fr_teams[0], it_teams[0], ge_teams[0])
        
#     elif recommended_teams[0] in bundesliga_array:
#         for i in recommended_teams:
#             if i in epl_array:
#                 en_teams.append(i)
#             if i in serie_a_array:
#                 it_teams.append(i)
#             if i in la_liga_array:
#                 sp_teams.append(i)
#             if i in ligue_1_array:
#                 fr_teams.append(i)
#         print(en_teams[0], fr_teams[0], it_teams[0], sp_teams[0])
    
#     else:
#         print('not applicable')
    
    return

# %%
df_stats_poss2[df_stats_poss2['CR'] > 22]
# Out:
#                       CR       ACR       CCOP      CCSP         FS  \
# Team
# Bayern Munich  22.852941  5.911765  10.000000  2.088235  10.176471
# Eibar          27.815789  7.000000   7.157895  2.000000  10.447368
# Juventus       22.921053  5.657895   9.657895  1.657895  12.552632
# Inter          28.710526  7.289474  10.631579  1.394737  13.078947
# Roma           22.500000  6.342105   9.947368  1.763158  10.552632
# SPAL 2013      22.736842  5.947368   7.026316  1.368421  14.684211
#
#                         P         DR        IBS       OBS        DSP  ...  \
# Team                                                                  ...
# Bayern Munich  571.000000  12.500000  12.794118  6.000000   9.323529  ...
# Eibar          310.052632   8.894737   9.289474  4.710526  10.210526  ...
# Juventus       455.868421   9.736842   9.631579  6.526316   8.526316  ...
# Inter          482.552632   7.526316  10.289474  6.394737   8.131579  ...
# Roma           372.657895   9.263158  10.710526  5.684211   9.236842  ...
# SPAL 2013      347.947368   7.210526   7.421053  4.736842  10.473684  ...
#
#                       AW         BR         DW        SV       AKS       PKC  \
# Team
# Bayern Munich  15.705882  64.029412  51.558824  1.411765  0.323529  0.176471
# Eibar          27.078947  67.789474  62.210526  2.184211  0.789474  0.105263
# Juventus       14.657895  57.000000  51.184211  2.210526  0.157895  0.105263
# Inter          14.184211  58.473684  50.184211  2.578947  0.184211  0.131579
# Roma           19.763158  58.473684  52.921053  3.105263  0.263158  0.184211
# SPAL 2013      15.710526  54.236842  52.000000  3.157895  0.131579  0.131579
#
#                       CL     PUNCH       LMT   poss
# Team
# Bayern Munich  10.117647  0.088235  0.029412  0.622
# Eibar          16.789474  0.315789  0.131579  0.520
# Juventus       15.815789  0.315789  0.000000  0.549
# Inter          15.184211  0.026316  0.000000  0.569
# Roma           20.000000  0.157895  0.000000  0.510
# SPAL 2013      21.052632  0.289474  0.052632  0.504
#
# [6 rows x 32 columns]

# %%
sns.jointplot(df_stats_poss2['P'], df_stats_poss2['CR'])

# %%
sns.distplot(df_stats_poss2['poss'], bins=10)

# %%
# Lyon Sampdoria Real Betis Borussia M.Gladbach
# Arsenal None ++++++++

# %%
df_stats_poss2[(df_stats_poss2.index == 'Arsenal') |
               (df_stats_poss2.index == 'Lyon') |
               (df_stats_poss2.index == 'Sampdoria') |
               (df_stats_poss2.index == 'Real Betis') |
               (df_stats_poss2.index == 'Borussia M.Gladbach')]
# Out:
#                             CR       ACR       CCOP      CCSP         FS  \
# Team
# Borussia M.Gladbach  16.617647  4.117647   7.588235  1.352941  10.735294
# Arsenal              15.921053  3.315789   7.473684  0.710526  12.105263
# Real Betis           15.526316  3.421053   6.736842  1.052632  14.605263
# Lyon                 17.947368  5.236842  10.052632  1.526316  12.605263
# Sampdoria            16.789474  3.657895   7.078947  0.763158  13.736842
#
#                               P         DR        IBS       OBS        DSP  \
# Team
# Borussia M.Gladbach  436.617647   8.205882   8.411765  5.147059   8.941176
# Arsenal              456.078947   7.921053   8.315789  4.078947  10.789474
# Real Betis           486.921053  11.473684   6.868421  4.815789  10.315789
# Lyon                 471.526316  12.026316  10.815789  6.894737  12.157895
# Sampdoria            425.447368   7.289474   6.921053  5.894737  12.157895
#
#                      ...         AW         BR         DW        SV       AKS  \
# Team                 ...
# Borussia M.Gladbach  ...  13.147059  56.970588  46.029412  3.382353  0.088235
# Arsenal              ...  14.868421  60.421053  50.552632  3.500000  0.394737
# Real Betis           ...  12.657895  54.368421  54.289474  2.710526  0.447368
# Lyon                 ...  16.684211  59.447368  57.368421  2.763158  0.289474
# Sampdoria            ...  13.000000  60.236842  50.105263  2.605263  0.526316
#
#                           PKC         CL     PUNCH       LMT   poss
# Team
# Borussia M.Gladbach  0.088235  17.294118  0.117647  0.058824  0.523
# Arsenal              0.184211  20.078947  0.473684  0.052632  0.561
# Real Betis           0.131579  16.868421  0.263158  0.157895  0.594
# Lyon                 0.131579  16.184211  0.210526  0.078947  0.582
# Sampdoria            0.210526  19.894737  0.342105  0.026316  0.537
#
# [5 rows x 32 columns]

# %%
df_stats_poss2.columns
# Out:
# Index(['CR', 'ACR', 'CCOP', 'CCSP', 'FS', 'P', 'DR', 'IBS', 'OBS', 'DSP', 'PK',
#        'FKCR', 'CRN', 'FKS', 'ALB', 'ATB', 'TOFF', 'BCS', 'INT', 'BLK', 'TKL',
#        'FC', 'AW', 'BR', 'DW', 'SV', 'AKS', 'PKC', 'CL', 'PUNCH', 'LMT',
#        'poss'],
#       dtype='object')

# %%
cols_2_drop11 = ['ACR', 'FS', 'DSP', 'PK', 'FKCR', 'FKS', 'ALB', 'ATB', 'TOFF', 'BCS', 'SV', 'PKC', 'PUNCH']

# %%
df_stats_poss3 = df_stats_poss2.drop(columns=cols_2_drop11)

# %%
df_stats_poss3.head()
# Out:
#                                CR       CCOP      CCSP           P         DR  \
# Team
# Bayern Munich           22.852941  10.000000  2.088235  571.000000  12.500000
# Borussia Dortmund       13.470588   6.882353  1.235294  524.352941  12.941176
# RasenBallsport Leipzig  18.117647   8.470588  1.558824  335.911765   9.264706
# Bayer Leverkusen        18.882353   8.970588  1.000000  536.764706   9.970588
# Borussia M.Gladbach     16.617647   7.588235  1.352941  436.617647   8.205882
#
#                               IBS       OBS       CRN        INT       BLK  \
# Team
# Bayern Munich           12.794118  6.000000  8.441176   9.882353  1.794118
# Borussia Dortmund        8.852941  4.352941  4.941176  11.323529  2.323529
# RasenBallsport Leipzig  10.147059  4.470588  5.588235  12.352941  2.058824
# Bayer Leverkusen        10.058824  5.735294  5.588235  10.705882  2.911765
# Borussia M.Gladbach      8.411765  5.147059  5.558824   9.117647  3.000000
#
#                               TKL         FC         AW         BR         DW  \
# Team
# Bayern Munich           13.647059   9.176471  15.705882  64.029412  51.558824
# Borussia Dortmund       14.617647   8.588235  13.970588  58.970588  52.441176
# RasenBallsport Leipzig  19.205882  13.676471  22.500000  65.705882  61.941176
# Bayer Leverkusen        17.588235  10.882353  16.882353  68.147059  55.441176
# Borussia M.Gladbach     14.705882   9.764706  13.147059  56.970588  46.029412
#
#                              AKS         CL       LMT   poss
# Team
# Bayern Munich           0.323529  10.117647  0.029412  0.622
# Borussia Dortmund       0.088235  18.470588  0.029412  0.568
# RasenBallsport Leipzig  0.500000  19.647059  0.088235  0.495
# Bayer Leverkusen        0.441176  18.882353  0.000000  0.577
# Borussia M.Gladbach     0.088235  17.294118  0.058824  0.523

# %%
cos_sim1 = cosine_similarity(df_stats_poss3)

# %%
# creating a Series for the movie titles so they are associated to an ordered numerical
# list I will use in the function to match the indexes
indices = pd.Series(df_stats_poss3.index)
#  defining the function that takes in movie title 
# as input and returns the top 10 recommended movies
def recommendations2(team, cosine_sim = cos_sim1):
    
    epl_array = (df_leagues['team'][df_leagues['league'] == 'EPL']).tolist()
    ligue_1_array = (df_leagues['team'][df_leagues['league'] == 'Ligue_1']).tolist()
    serie_a_array = (df_leagues['team'][df_leagues['league'] == 'Serie_A']).tolist()
    la_liga_array = (df_leagues['team'][df_leagues['league'] == 'La_liga']).tolist()
    bundesliga_array = (df_leagues['team'][df_leagues['league'] == 'Bundesliga']).tolist()
    
    en_teams = []
    fr_teams = []
    it_teams = []
    sp_teams = []
    ge_teams = []
    
    # initializing the empty list of recommended movies
    recommended_teams = []
    
    # gettin the index of the movie that matches the title
    idx = indices[indices == team].index[0]
    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)
    # getting the indexes of the 10 most similar movies
    all_indexes = list(score_series.index)
    
    # populating the list with the titles of the best 10 matching movies
    for i in all_indexes:
        recommended_teams.append(list(df_stats_poss3.index)[i])
    
    if recommended_teams[0] in epl_array:
        for i in recommended_teams:
            if i in ligue_1_array:
                fr_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
            
        print(f"France: {fr_teams[0]}")
        print(f"Italy: {it_teams[0]}")
        print(f"Spain: {sp_teams[0]}" )
        print(f"Germany: {ge_teams[0]}")
    
    elif recommended_teams[0] in ligue_1_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
        print(f"England: {en_teams[0]}")
        print(f"Italy: {it_teams[0]}")
        print(f"Spain: {sp_teams[0]}" )
        print(f"Germany: {ge_teams[0]}")
    
    elif recommended_teams[0] in serie_a_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in ligue_1_array:
                fr_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
        print(f"England: {en_teams[0]}")
        print(f"France: {fr_teams[0]}")
        print(f"Spain: {sp_teams[0]}" )
        print(f"Germany: {ge_teams[0]}")
    
    elif recommended_teams[0] in la_liga_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in ligue_1_array:
                fr_teams.append(i)
            if i in bundesliga_array:
                ge_teams.append(i)
        print(f"England: {en_teams[0]}")
        print(f"France: {fr_teams[0]}")
        print(f"Italy: {it_teams[0]}" )
        print(f"Germany: {ge_teams[0]}")
        
    elif recommended_teams[0] in bundesliga_array:
        for i in recommended_teams:
            if i in epl_array:
                en_teams.append(i)
            if i in serie_a_array:
                it_teams.append(i)
            if i in la_liga_array:
                sp_teams.append(i)
            if i in ligue_1_array:
                fr_teams.append(i)
        print(f"England: {en_teams[0]}")
        print(f"France: {fr_teams[0]}")
        print(f"Italy: {it_teams[0]}" )
        print(f"Spain: {sp_teams[0]}")
    
    else:
        print('not applicable')
    
    return

# %%
recommendations2('Mainz 05')
# Out:
# England: Everton
# France: Montpellier
# Italy: Fiorentina
# Spain: Girona

# %%
for team in df_leagues['team']:
    print(f"the recommendations for {team} are ", recommendations(team))
# Out:
# Manchester City Lyon Atalanta Real Madrid
# the recommendations for Bayern Munich are  None
# Chelsea Paris Saint Germain Atalanta Barcelona
# the recommendations for Borussia Dortmund are  None
# Everton Marseille Atalanta Eibar
# the recommendations for RasenBallsport Leipzig are  None
# Liverpool Lyon Atalanta Real Madrid
# the recommendations for Bayer Leverkusen are  None
# Manchester United Paris Saint Germain Napoli Barcelona
# the recommendations for Borussia M.Gladbach are  None
# Wolverhampton Wanderers Strasbourg Juventus Eibar
# the recommendations for Wolfsburg are  None
# Everton Nantes Torino Eibar
# the recommendations for Eintracht Frankfurt are  None
# Manchester City Saint-Etienne Roma Valencia
# the recommendations for Werder Bremen are  None
# Manchester City Lyon Atalanta Real Madrid
# the recommendations for Hoffenheim are  None
# Newcastle United Montpellier Udinese Leganes
# the recommendations for Fortuna Duesseldorf are  None
# Brighton Caen Parma Calcio 1913 Villarreal
# the recommendations for Hertha Berlin are  None
# Fulham Montpellier Lazio Valencia
# the recommendations for Mainz 05 are  None
# Newcastle United Caen Udinese Espanyol
# the recommendations for Freiburg are  None
# Everton Nantes Genoa Atletico Madrid
# the recommendations for Schalke 04 are  None
# Brighton Dijon Chievo SD Huesca
# the recommendations for Augsburg are  None
# Cardiff Guingamp Frosinone Alaves
# the recommendations for VfB Stuttgart are  None
# Cardiff Caen Parma Calcio 1913 Girona
# the recommendations for Hannover 96 are  None
# Cardiff Angers Parma Calcio 1913 Leganes
# the recommendations for Nuernberg are  None
# Paris Saint Germain Napoli Real Madrid Bayern Munich
# the recommendations for Manchester City are  None
# Paris Saint Germain Atalanta Real Madrid Bayern Munich
# the recommendations for Liverpool are  None
# Paris Saint Germain Napoli Barcelona Bayern Munich
# the recommendations for Chelsea are  None
# Paris Saint Germain Napoli Barcelona Bayer Leverkusen
# the recommendations for Tottenham are  None
# Paris Saint Germain Empoli Sevilla Borussia Dortmund
# the recommendations for Arsenal are  None
# Paris Saint Germain Napoli Barcelona Borussia M.Gladbach
# the recommendations for Manchester United are  None
# Caen Chievo Atletico Madrid Augsburg
# the recommendations for Wolverhampton Wanderers are  None
# Marseille Genoa Eibar RasenBallsport Leipzig
# the recommendations for Everton are  None
# Nice Empoli Atletico Madrid Hannover 96
# the recommendations for West Ham are  None
# Marseille Atalanta Eibar VfB Stuttgart
# the recommendations for Leicester are  None
# Toulouse Sampdoria Alaves VfB Stuttgart
# the recommendations for Watford are  None
# Reims Udinese Atletico Madrid Hannover 96
# the recommendations for Crystal Palace are  None
# the recommendations for Rennes are  None
# Huddersfield Chievo Girona Wolfsburg
# the recommendations for Strasbourg are  None
# Everton Genoa Eibar Schalke 04
# the recommendations for Nantes are  None
# Cardiff Parma Calcio 1913 Alaves Nuernberg
# the recommendations for Angers are  None
# Huddersfield Torino Real Valladolid Freiburg
# the recommendations for Bordeaux are  None
# Watford Bologna Alaves Nuernberg
# the recommendations for Toulouse are  None
# Brighton Chievo Girona Nuernberg
# the recommendations for Amiens are  None
# Everton SPAL 2013 Real Valladolid Nuernberg
# the recommendations for Monaco are  None
# Huddersfield Torino Alaves Augsburg
# the recommendations for Dijon are  None
# Brighton Chievo Girona Hannover 96
# the recommendations for Caen are  None
# Huddersfield Genoa Alaves VfB Stuttgart
# the recommendations for Guingamp are  None
# Manchester City Lyon Real Madrid Bayern Munich
# the recommendations for Juventus are  None
# Chelsea Lyon Real Madrid Hoffenheim
# the recommendations for Napoli are  None
# Manchester City Paris Saint Germain Real Madrid Hoffenheim
# the recommendations for Atalanta are  None
# Manchester City Saint-Etienne Real Madrid Bayern Munich
# the recommendations for Inter are  None
# Manchester City Saint-Etienne Real Madrid Hoffenheim
# the recommendations for AC Milan are  None
# Manchester City Lyon Real Madrid Hoffenheim
# the recommendations for Roma are  None
# Huddersfield Montpellier Getafe Eintracht Frankfurt
# the recommendations for Torino are  None
# Manchester City Lyon Real Madrid Hoffenheim
# the recommendations for Lazio are  None
# Arsenal Lille Real Betis Bayer Leverkusen
# the recommendations for Sampdoria are  None
# Cardiff Nantes Alaves Freiburg
# the recommendations for Bologna are  None
# Manchester United Lille Real Betis Borussia M.Gladbach
# the recommendations for Sassuolo are  None
# Fulham Amiens Espanyol Freiburg
# the recommendations for Udinese are  None
# Bournemouth Monaco Girona Nuernberg
# the recommendations for SPAL 2013 are  None
# Manchester City Nimes Valencia Hoffenheim
# the recommendations for Fiorentina are  None
# Brighton Strasbourg Girona Werder Bremen
# the recommendations for Cagliari are  None
# Brighton Amiens Espanyol Freiburg
# the recommendations for Parma Calcio 1913 are  None
# Southampton Nimes Leganes Schalke 04
# the recommendations for Genoa are  None
# Arsenal Strasbourg Levante Borussia M.Gladbach
# the recommendations for Empoli are  None
# Brighton Amiens Girona Freiburg
# the recommendations for Frosinone are  None
# Brighton Caen Girona Freiburg
# the recommendations for Chievo are  None

# %%
df_scaled = pd.read_csv('df_scaled.csv', index_col=0)

# %%
df_scaled2.head()
# Out:
#                         ppda_coef      deep         S        CR      CCOP  \
# Team
# Bayern Munich           -0.898850  2.973806  2.775593  1.611378  1.795907
# Borussia Dortmund        1.390868  0.807589  0.118582 -1.716195 -0.305416
# RasenBallsport Leipzig  -0.117029  0.509248  0.807436 -0.068055  0.765069
# Bayer Leverkusen        -0.271538  1.067016  1.341650  0.203158  1.102074
# Borussia M.Gladbach      2.184874  0.405477  0.273222 -0.600050  0.170355
#
#                             CCSP         P        DR       IBS       OBS  ...  \
# Team                                                                      ...
# Bayern Munich           2.673514  2.370940  2.120765  3.188202  0.987291  ...
ns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1677                 blocks = [
# -> 1678                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1679                 ]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3266
# -> 3267     return klass(values, ndim=ndim, placement=placement)
#    3268
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     127                 "Wrong number of items passed {val}, placement implies "
# --> 128                 "{mgr}".format(val=len(self.values), mgr=len(self.mgr_locs))
#     129             )
#
# ValueError: Wrong number of items passed 30, placement implies 75
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-bae837e828ad> in <module>
# ----> 1 df_pca = pd.DataFrame(data = transformed, index = df_scaled.index, columns = df_scaled.columns)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     438                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     439             else:
# --> 440                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     441
#     442         # For data is list-like, or Iterable (will consume into list)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     211         block_values = [values]
#     212
# --> 213     return create_block_manager_from_blocks(block_values, [columns, index])
#     214
#     215
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1686         blocks = [getattr(b, "values", b) for b in blocks]
#    1687         tot_items = sum(b.shape[0] for b in blocks)
# -> 1688         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    1689
#    1690
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in construction_error(tot_items, block_shape, axes, e)
#    1717         raise ValueError("Empty data passed with indices specified.")
#    1718     raise ValueError(
# -> 1719         "Shape of passed values is {0}, indices imply {1}".format(passed, implied)
#    1720     )
#    1721
#
# ValueError: Shape of passed values is (98, 30), indices imply (98, 75)

# %%
df_pca.head()
# Out:
#                                xG      npxG  ppda_coef      deep         G  \
# Team
# Bayern Munich           17.707501  2.299785  -4.160416 -0.226125  0.219146
# Borussia Dortmund        7.113854 -3.538504   1.903248 -2.610587  0.157484
# RasenBallsport Leipzig   4.749810  2.192070   0.178452 -4.259053  1.489670
# Bayer Leverkusen         7.398632 -0.818004  -0.167547 -0.971495  2.328940
# Borussia M.Gladbach      3.229938 -3.727765  -1.617028  1.680398 -1.940659
#
#                                A       AOP       ASP         S       SOG  ...  \
# Team                                                                      ...
# Bayern Munich          -1.123547  0.424808 -1.676861  3.443035  0.864963  ...
# Borussia Dortmund       0.202333 -0.403019 -1.138047  2.620691  3.491337  ...
# RasenBallsport Leipzig -1.372841 -0.309159 -0.146701 -2.055781 -0.668068  ...
# Bayer Leverkusen        0.799063 -2.448867 -0.295838 -0.023522 -0.960408  ...
# Borussia M.Gladbach     0.330544  2.722692 -1.041985  1.594908  0.890639  ...
#
#                             OBSV       AKS       PKC       PKF          PKSV  \
# Team
# Bayern Munich           0.000002  0.000578  0.000615 -0.004219  2.652279e-16
# Borussia Dortmund       0.007006  0.004054  0.000705 -0.003459  4.993779e-16
# RasenBallsport Leipzig  0.001699 -0.012231 -0.002507  0.000573  3.406233e-16
# Bayer Leverkusen       -0.010039 -0.003547  0.000625  0.001959  1.823016e-16
# Borussia M.Gladbach    -0.001908  0.004653  0.001682  0.002755  4.685842e-17
#
#                                   CL           ECL         PUNCH  \
# Team
# Bayern Munich          -2.868343e-16  2.828384e-16 -7.735784e-16
# Borussia Dortmund      -6.726011e-16  2.823641e-16  5.550646e-16
# RasenBallsport Leipzig  2.508274e-16 -1.135550e-16 -9.502899e-17
# Bayer Leverkusen        4.281290e-16  6.973254e-16  4.177970e-16
# Borussia M.Gladbach     4.074326e-16  6.447610e-16 -8.646598e-16
#
#                                  LMT          poss
# Team
#temp = pd.DataFrame(str_loading_1, columns = ['loadings'])

# %%
str_loading_1.sort_values(ascending=False)
# Out:
# TBOX            0.917777
# poss            0.915603
# P               0.907339
# deep            0.891978
# S               0.882693
# IBS             0.882346
# CRN             0.858074
# CCOP            0.841904
# oppda_coef      0.814252
# BCS             0.775659
# ATB             0.699429
# DR              0.629074
# CRNCR           0.611923
# OBS             0.536200
# FKS             0.390460
# TOFF            0.275844
# CR              0.245863
# ALB             0.196555
# BR              0.192514
# CCSP            0.087321
# AKS             0.056480
# LMT            -0.187137
# FKCR           -0.280544
# PUNCH          -0.341051
# TKL            -0.343006
# DW             -0.416935
# FC             -0.432278
# ppda_coef      -0.482893
# INT            -0.486888
# BLK            -0.546183
# AW             -0.592785
# deep_allowed   -0.666594
# CL             -0.811196
# dtype: float64

# %%
index=df_scaled2.columns

# %%
plt.figure(figsize = (10,10))
plt.bar(index, pca.explained_variance_ratio_)
plt.title('Scree plot for PCA')
plt.xlabel('Num of components')
plt.ylabel('proportion of explained variance')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-224-d467873d6c94> in <module>
#       1 plt.figure(figsize = (10,10))
# ----> 2 plt.bar(index, pca.explained_variance_ratio_)
#       3 plt.title('Scree plot for PCA')
#       4 plt.xlabel('Num of components')
#       5 plt.ylabel('proportion of explained variance')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2438     return gca().bar(
#    2439         x, height, width=width, bottom=bottom, align=align,
# -> 2440         **({"data": data} if data is not None else {}), **kwargs)
#    2441
#    2442
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('explained variance ratio')
# Out:
# Text(0, 0.5, 'explained variance ratio')

# %%
k_means = KMeans(n_clusters=3) 

# Run the clustering algorithm
k_means.fit(df_scaled2) 

# Generate cluster index values for each row
cluster_assignments = k_means.predict(df_scaled2)

# %%
k_means.labels_
# Out:
# array([1, 1, 0, 1, 1, 0, 0, 2, 1, 2, 2, 2, 2, 0, 2, 2, 2, 2, 1, 1, 1, 1,
#        1, 1, 2, 0, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 0, 1, 2, 1, 0,
#        2, 0, 0, 2, 1, 0, 2, 2, 2, 0, 0, 2, 0, 0, 1, 0, 1, 0, 0, 0, 0, 0,
#        0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2, 0, 1, 1, 1, 1, 1, 1, 0, 1, 0, 0,
#        1, 2, 2, 0, 2, 2, 0, 2, 2, 2], dtype=int32)

# %%
cluster_assignments
# Out:
# array([1, 1, 0, 1, 1, 0, 0, 2, 1, 2, 2, 2, 2, 0, 2, 2, 2, 2, 1, 1, 1, 1,
#        1, 1, 2, 0, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 0, 1, 2, 1, 0,
#        2, 0, 0, 2, 1, 0, 2, 2, 2, 0, 0, 2, 0, 0, 1, 0, 1, 0, 0, 0, 0, 0,
#        0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 2, 0, 1, 1, 1, 1, 1, 1, 0, 1, 0, 0,
#        1, 2, 2, 0, 2, 2, 0, 2, 2, 2], dtype=int32)

# %%
print(calinski_harabasz_score(df_scaled2, cluster_assignments))
# Out:
# 22.115656218581105

# %%
df_labels = pd.DataFrame(cluster_assignments, columns=['cluster'], index=df_scaled2.index)

# %%
df_labels.head()
# Out:
#                         cluster
# Team
# Bayern Munich                 1
# Borussia Dortmund             1
# RasenBallsport Leipzig        0
# Bayer Leverkusen              1
# Borussia M.Gladbach           1

# %%
df_labels[df_labels['cluster'] == 0]
# Out:
#                         cluster
# Team
# RasenBallsport Leipzig        0
# Wolfsburg                     0
# Eintracht Frankfurt           0
# Schalke 04                    0
# Everton                       0
# Leicester                     0
# Watford                       0
# Atletico Madrid               0
# Getafe                        0
# Athletic Club                 0
# Real Sociedad                 0
# Eibar                         0
# Celta Vigo                    0
# Real Valladolid               0
# SD Huesca                     0
# Rayo Vallecano                0
# Lille                         0
# Saint-Etienne                 0
# Marseille                     0
# Montpellier                   0
# Nice                          0
# Reims                         0
# Nimes                         0
# Rennes                        0
# Nantes                        0
# Bordeaux                      0
# Toulouse                      0
# Monaco                        0
# Dijon                         0
# Guingamp                      0
# Torino                        0
# Sampdoria                     0
# Bologna                       0
# Fiorentina                    0
# Genoa                         0

# %%
df_scaled2.columns
# Out:
# Index(['ppda_coef', 'deep', 'CR', 'P', 'DR', 'IBS', 'OBS', 'TBOX', 'FKCR',
#        'CRN', 'CRNCR', 'FKS', 'TOFF', 'BCS', 'oppda_coef', 'deep_allowed',
#        'INT', 'BLK', 'TKL', 'FC', 'AW', 'BR', 'DW', 'AKS', 'CL', 'PUNCH',
#        'LMT', 'poss'],
#       dtype='object')

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=df_scaled2['poss'], y=df_scaled2['deep_allowed'], hue=df_labels['cluster'])

# %%
distortions = []
for i in range(1, 11):
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(df_scaled2)
    distortions.append(km.inertia_)

# plot
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
df_scaled.columns
# Out:
# Index(['xG', 'npxG', 'ppda_coef', 'deep', 'G', 'A', 'AOP', 'ASP', 'S', 'SOG',
#        'CR', 'ACR', 'CC', 'BCC', 'CCOP', 'CCSP', 'FS', 'P', 'AP', 'ACRO', 'DR',
#        'IBS', 'IBSOG', 'IBG', 'OBS', 'OBSOG', 'OBG', 'TOUCH', 'TBOX', 'PK',
#        'PKG', 'PKM', 'PKSVD', 'FKCR', 'FKACR', 'CRN', 'CRNCR', 'CRNW', 'FKS',
#        'FKSOG', 'FKG', 'ALB', 'ATB', 'TOFF', 'BCM', 'BCS', 'ATTDR', 'xGA',
#        'npxGA', 'oppda_coef', 'deep_allowed', 'INT', 'BLK', 'TKL', 'TKLW',
#        'FC', 'AW', 'BR', 'DW', 'DSP', 'OWN', 'GC', 'CS', 'SV', 'IBSV', 'OBSV',
#        'AKS', 'PKC', 'PKF', 'PKSV', 'CL', 'ECL', 'PUNCH', 'LMT', 'poss'],
#       dtype='object')

# %%
cols_2_drop5 = ['xG', 'npxG', 'xGA', 'npxGA', 'G', 'A', 'TKLW', 'BCC', 'CC', 'ACRO', 'AP', 'IBSOG', 'IBG', 'OBSOG', 
                'TOUCH', 'PKG', 'CRNW', 'FKSOG', 'IBSV', 'OBSV', 'CS', 'PKF', 'ECL', 'BCM', 'ATTDR', 'SOG', 
                'AOP', 'ASP', 'OBG', 'OWN', 'PKM', 'PKSVD', 'FKACR', 'FKG', 'GC', 'PKSV', 'ACR', 'FS', 'PK', 'DSP', 
                'SV', 'PKC']

# %%
df_scaled2 = df_scaled.drop(columns=cols_2_drop5)

# %%
df_scaled2.columns
# Out:
# Index(['ppda_coef', 'deep', 'S', 'CR', 'CCOP', 'CCSP', 'P', 'DR', 'IBS', 'OBS',
#        'TBOX', 'FKCR', 'CRN', 'CRNCR', 'FKS', 'ALB', 'ATB', 'TOFF', 'BCS',
#        'oppda_coef', 'deep_allowed', 'INT', 'BLK', 'TKL', 'FC', 'AW', 'BR',
#        'DW', 'AKS', 'CL', 'PUNCH', 'LMT', 'poss'],
#       dtype='object')

# %%
df_scaled2.to_csv(r'/Users/andrewtriola/Documents/flatiron/final_project/final_project_repo/df_scaled2.csv')

# %%
df_stats_poss3.to_csv(r'/Users/andrewtriola/Documents/flatiron/final_project/final_project_repo/df_stats_poss3.csv')

# %%
df_scaled2 = pd.read_csv('df_scaled2.csv', index_col='Team')

# %%
df_scaled2.head()
# Out:
#                         ppda_coef      deep        CR         P        DR  \
# Team
# Bayern Munich           -0.898850  2.973806  1.611378  2.370940  2.120765
# Borussia Dortmund        1.390868  0.807589 -1.716195  1.854117  2.366656
# RasenBallsport Leipzig  -0.117029  0.509248 -0.068055 -0.233706  0.317571
# Bayer Leverkusen        -0.271538  1.067016  0.203158  1.991632  0.710995
# Borussia M.Gladbach      2.184874  0.405477 -0.600050  0.882059 -0.272566
#
#                              IBS       OBS      TBOX      FKCR       CRN  ...  \
# Team                                                                      ...
# Bayern Munich           3.188202  0.987291  3.397046  0.739975  3.731464  ...
# Borussia Dortmund       0.630185 -0.790167  0.960062  0.388823 -0.090346  ...
# RasenBallsport Leipzig  1.470131 -0.663206  0.857572  0.827763  0.616207  ...
# Bayer Leverkusen        1.412862  0.701628  1.227675 -0.664633  0.616207  ...
# Borussia M.Gladbach     0.343840  0.066822  0.174306 -0.576845  0.584091  ...
#
#                              TKL        FC        AW        BR        DW  \
# Team
# Bayern Munich          -2.081226 -1.795271 -0.716088  1.360479 -0.948188
# Borussia Dortmund      -1.469764 -2.115407 -1.202503 -0.403610 -0.713429
# RasenBallsport Leipzig  1.420784  0.653768  1.188352  1.945090  1.814138
# Bayer Leverkusen        0.401681 -0.866877 -0.386314  2.796366  0.084750
# Borussia M.Gladbach    -1.414177 -1.475135 -1.433344 -1.101041 -2.419341
#
#                              AKS        CL     PUNCH       LMT      poss
# Team
# Bayern Munich           0.407311 -3.083852 -1.680898 -0.596272  2.474804
# Borussia Dortmund      -1.157638 -0.662533  0.096810 -0.596272  1.379674
# RasenBallsport Leipzig  1.581023 -0.321502 -1.147586  0.708380 -0.100780
# Bayer Leverkusen        1.189786 -0.543172 -0.614273 -1.248599  1.562196
# Borussia M.Gladbach    -1.157638 -1.003564 -1.503127  0.056054  0.467065
#
# [5 rows x 28 columns]
